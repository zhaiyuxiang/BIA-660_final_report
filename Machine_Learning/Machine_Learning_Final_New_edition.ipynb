# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns

# %%
df_Venetian=pd.read_csv('/Users/richard/Desktop/BIA660D_Group_6_Project-master/data_gathering/Venetian_overall_data.csv')

# %%
df_wynn=pd.read_csv('/Users/richard/Desktop/BIA660D_Group_6_Project-master/data_gathering/wynn_overall_data.csv')

# %%
df_Caesars=pd.read_csv('/Users/richard/Desktop/BIA660D_Group_6_Project-master/data_gathering/Caesar_overall_data.csv')

# %%
df_Caesars.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
df_new=pd.concat([df_Venetian, df_wynn],axis=0)

# %%
df_new.head()
# Out:
#    Unnamed: 0       Name               Nationality                      Date  \
# 0           0      Jenna  United States of America  Reviewed: April 18, 2018
# 1           1      Clare            United Kingdom  Reviewed: April 18, 2018
# 2           2     Eugene  United States of America  Reviewed: April 17, 2018
# 3           3     AM4Fun                  Pakistan  Reviewed: April 17, 2018
# 4           4  Anonymous  United States of America  Reviewed: April 16, 2018
#
#    Score                                              Topic  \
# 0   10.0        It was a Dream Come True... Mahalos from AZ
# 1   10.0                                 Room with a view!
# 2    7.5  Central to the Mirage where we bought Boys to ...
# 3    8.8  Theme, atmosphere, nice easy feel about the Re...
# 4    6.7                  We stayed at Palazzo tower suits.
#
#                                                 Tags History reviews
# 0  • Leisure trip• Couple• Venetian Luxury Suite ...       2 Reviews
# ...

# %%
df_new.to_csv('/Users/richard/Desktop/BIA660D_Group_6_Project-master/data_gathering/Overall.csv')

# %%
df_new.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
df_new=pd.concat([df_Caesars, df_new],axis=0)

# %%
import csv
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()
spamreader =df_new['Topic']
comments = []
list_ok=[]
for i in spamreader:
    comments.append(i)
#print("Sentiment Analysis for " + filename + ":")
for comment in spamreader:
#         print(comment)
    ss = sid.polarity_scores(comment)
        #print(type(ss))
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]))
        list_ok.append(ss)
# Out:
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.729,
# neg: 0.0,
# neu: 0.163,
# pos: 0.837,
# compound: 0.0382,
# neg: 0.0,
# neu: 0.929,
# pos: 0.071,
# compound: 0.7783,
# neg: 0.0,
# neu: 0.595,
# pos: 0.405,
# compound: -0.5413,
# neg: 0.777,
# neu: 0.223,
# pos: 0.0,
# compound: 0.2492,
# neg: 0.0,
# neu: 0.778,
# pos: 0.222,
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: -0.6588,
# neg: 0.687,
# neu: 0.313,
# pos: 0.0,
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.5267,
# neg: 0.0,
# neu: 0.673,
# pos: 0.327,
# compound: 0.2003,
# neg: 0.132,
# neu: 0.661,
# pos: 0.207,
# compound: 0.7964,
# neg: 0.0,
# neu: 0.36,
# pos: 0.64,
# compound: -0.5994,
# neg: 0.308,
# neu: 0.692,
# pos: 0.0,
# compound: 0.93,
# neg: 0.0,
# neu: 0.337,
# pos: 0.663,
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: -0.34,
# neg: 0.199,
# neu: 0.674,
# pos: 0.127,
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# ...

# %%
j = 0
tmp = pd.DataFrame(list_ok[0],index=[0])
for i in range(3,len(list_ok)):
    if i%4 == 0:
        j += 1
        tmp = pd.concat([tmp,pd.DataFrame(list_ok[i],index = [j])])

# %%
df_new.reset_index(drop=True, inplace=True)

# %%
df_update=pd.concat([df_new,tmp],axis=1)
df_update.head()
# Out:
#        Name               Nationality                      Date  Score  \
# 0     Diego                Costa Rica  Reviewed: April 19, 2018    8.3
# 1  Adelaide                 Australia  Reviewed: April 19, 2018    9.6
# 2    Judith  United States of America  Reviewed: April 17, 2018    4.2
# 3    Moises  United States of America  Reviewed: April 15, 2018    6.3
# 4      Rrss                    Canada  Reviewed: April 15, 2018    2.5
#
#                                                Topic  \
# 0                             Location and room size
# 1                                      A GREAT stay!
# 2  Could not wait to leave and will never come ba...
# 3  Had an overall comforting overnight stay in Ve...
# 4                                 Very disappointing
#
#                                                 Tags History reviews  \
# 0  • Business trip• Group• Forum Classic, 1 King ...       3 Reviews
# 1  • Leisure trip• Group• Julius Deluxe Room, 1 K...       3 Reviews
# ...

# %%
Overall_review=[]
for i in df_update['History reviews']:
    b=i.strip(' Reviews')
    z=b.strip(' review')
    Overall_review.append(z)

# %%
Date_new=[]
for i in df_update['Date']:
    a=i.strip('Reviewed: ')
    Date_new.append(a)

# %%
dummy_ranks = pd.get_dummies(df_update['Nationality'], prefix='Nationality')

# %%
def Business_trip(text):
    if 'Business trip' in text:
        Business_trip=1
    else:
        Business_trip=0
    return Business_trip

# %%
def Leisure(text):
    if 'Leisure trip' in text:
        Leisure_trip=1
    else:
        Leisure_trip=0
    return Leisure_trip

# %%
def group(text):
    if 'Group' in text:
        Group=1
    else:
        Group=0
    return Group

# %%
def Couple(text):
    if 'Couple' in text:
        Couple=1
    else:
        Couple=0
    return Couple

# %%
def Family(text):
    if 'Family' in text:
        Family=1
    else:
        Family=0
    return Family

# %%
def Friends(text):
    if 'Friends' in text:
        Friends=1
    else:
        Friends=0
    return Friends

# %%
def solo(text):
    if 'solo' in text:
        solo=1
    else:
        solo=0
    return solo

# %%
df_update['business_trip']=df_update['Tags'].apply(Business_trip)
df_update['leisure']=df_update['Tags'].apply(Leisure)
df_update['group']=df_update['Tags'].apply(group)
df_update['couple']=df_update['Tags'].apply(Couple)
df_update['family']=df_update['Tags'].apply(Family)
df_update['friends']=df_update['Tags'].apply(Friends)
df_update['solo']=df_update['Tags'].apply(solo)

# %%
df_latest=pd.concat([df_update,dummy_ranks],axis=1)

# %%
df_latest.drop(['Tags'],axis=1, inplace=True)

# %%
c={"Review_times" : Overall_review,
   "Date_new" : Date_new}

df_test=pd.DataFrame(c)

# %%
df_latest=pd.concat([df_latest,df_test],axis=1)

# %%
df_latest.drop(['Date', 'History reviews'],axis=1, inplace=True)

# %%
df_latest.head()
# Out:
#        Name               Nationality  Score  \
# 0     Diego                Costa Rica    8.3
# 1  Adelaide                 Australia    9.6
# 2    Judith  United States of America    4.2
# 3    Moises  United States of America    6.3
# 4      Rrss                    Canada    2.5
#
#                                                Topic  compound    neg    neu  \
# 0                             Location and room size    0.0000  0.000  1.000
# 1                                      A GREAT stay!    0.7290  0.000  0.163
# 2  Could not wait to leave and will never come ba...    0.0382  0.000  0.929
# 3  Had an overall comforting overnight stay in Ve...    0.7783  0.000  0.595
# 4                                 Very disappointing   -0.5413  0.777  0.223
#
#      pos  business_trip  leisure      ...       \
# 0  0.000              1        0      ...
# 1  0.837              0        1      ...
# 2  0.071              0        0      ...
# 3  0.405              0        1      ...
# ...

# %%
df_latest.to_csv('/Users/richard/Desktop/BIA660D_Group_6_Project-master/data_gathering/Data_completed.csv')

# %%
fig, ax = plt.subplots()
ax.scatter(x = df_latest['compound'], y = df_latest['Score'])
plt.ylabel('Rating', fontsize=13)
plt.xlabel('Compound', fontsize=13)
plt.show()

# %%
df_update.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from scipy import stats
from scipy.stats import norm
sns.distplot(df_latest['pos'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_latest['pos'], plot=plt)

# %%
plt.show()

# %%
sns.distplot(df_latest['neu'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_latest['neu'], plot=plt)

# %%
plt.show()

# %%
corr = df_update.corr()

sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
plt.show()

# %%
corr
# Out:
#                   Score  compound       neg       neu       pos  \
# Score          1.000000  0.372489 -0.365287 -0.135690  0.289068
# compound       0.372489  1.000000 -0.526467 -0.594184  0.811043
# neg           -0.365287 -0.526467  1.000000 -0.171640 -0.260168
# neu           -0.135690 -0.594184 -0.171640  1.000000 -0.902827
# pos            0.289068  0.811043 -0.260168 -0.902827  1.000000
# business_trip -0.068812 -0.040064  0.017187  0.021653 -0.028013
# leisure        0.060838  0.040016 -0.009218 -0.025695  0.030381
# group         -0.027345 -0.001795  0.027819 -0.016141  0.004940
# couple         0.071350  0.035028 -0.024051 -0.004162  0.012230
# family        -0.055811 -0.033418  0.006259  0.017399 -0.018571
# friends             NaN       NaN       NaN       NaN       NaN
# solo                NaN       NaN       NaN       NaN       NaN
#
#                business_trip   leisure     group    couple    family  friends  \
# ...

# %% [markdown]
# ### Modeling

# %%
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from sklearn.model_selection import GridSearchCV
from sklearn import svm
from sklearn.model_selection import cross_val_score

# %%
y=df_latest['Score']
DF1=df_latest.drop(['Name','Nationality','Score','friends','solo', 'Date_new'],axis=1)

# %%
def remove_punctuation(text):
    '''a function for removing punctuation'''
    import string
    # replacing the punctuations with no space, 
    # which in effect deletes the punctuation marks 
    translator = str.maketrans('', '', string.punctuation)
    # return the text stripped of punctuation marks
    return text.translate(translator)

# %%
sw = stopwords.words('english')
def stopwords(text):
    '''a function for removing the stopword'''
    # removing the stop words and lowercasing the selected words
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    # joining the list of words with space separator
    return " ".join(text)

# %%
stemmer = SnowballStemmer("english")

def stemming(text):    
    '''a function which stems each word in the given text'''
    text = [stemmer.stem(word) for word in text.split()]
    return " ".join(text)

# %%
DF1['Topic']=DF1['Topic'].apply(remove_punctuation)
DF1['Topic']=DF1['Topic'].apply(stopwords)
DF1['Topic']=DF1['Topic'].apply(stemming)

# %%
cv = CountVectorizer()
data = cv.fit_transform(DF1.Topic)

# %%
DF2=pd.concat([pd.DataFrame(data.toarray()), DF1], axis=1)

# %%
DF2.drop(['Topic'],axis=1,inplace=True)

# %%
y2=[]
for i in y:
    if i>=8:
        a=1
    else:
        a=0
    y2.append(a)
    
y1=[]
for i in y:
    if 6<=i<8:
        b=1
    else:
        b=0
    y1.append(b)

y0=[]
for i in y:
    if i<6:
        c=1
    else:
        c=0
    y0.append(c)

# %% [markdown]
# ## Multi-class Prediction

# %% [markdown]
# ### Label 2

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.model_selection import train_test_split
x_train2,x_test2,y_train2,y_test2=train_test_split(DF2,y2,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
param_grid = {'C': np.linspace(1, 100, 1), 'penalty': ['l1', 'l2']}
grid_lr = GridSearchCV(lr, param_grid=param_grid, cv=10, n_jobs=1, scoring='roc_auc')

# %%
grid_lr.fit(x_train2,y_train2)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': array([ 1.]), 'penalty': ['l1', 'l2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
lr=grid_lr.best_estimator_
# lr=LogisticRegression(C=1, penalty='l1')
#cross_val_score(lr, X=DF2, y=y_new, cv=10, scoring='accuracy').mean()

# %%
grid_lr.best_score_
# Out:
# 0.77423668375306443

# %%
lr.fit(x_train2,y_train2)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
from sklearn import metrics
from sklearn.metrics import roc_curve
y_pred_lr=lr.predict_proba(x_test2)[:, 1]
fpr_lr, tpr_lr, _ = roc_curve(y_test2, y_pred_lr)
plt.plot(fpr_lr, tpr_lr, label='LR')
plt.show()
metrics.auc(fpr_lr, tpr_lr)
# Out:
# 0.79037589176874967

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier_NB=GaussianNB()
classifier_NB.fit(x_train2, y_train2)
y_pred_NB_prob=classifier_NB.predict_proba(x_test2)[:,1]
cm_NB=confusion_matrix(y_test2,y_pred_NB)
print(cm_NB)
# Out:
# [[274  33]
#  [671 144]]

# %%
from sklearn.metrics import roc_auc_score
NB_auc=roc_auc_score(y_test2, y_pred_NB_prob)
NB_auc
# Out:
# 0.53678783397613961

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
#sample_leaf_options = [1,5,10,50,100,200,500]
#for leaf_size in sample_leaf_options:
    #model = RandomForestClassifier(n_estimators = 200, oob_score = True, n_jobs = -1,random_state =50,max_features = "auto", min_samples_leaf = leaf_size)
    #model.fit(DF2,y_new)
    #print(cross_val_score(model, X=DF2, y=y_new, cv=10, scoring='accuracy').mean())
classifier=RandomForestClassifier(random_state=0)

# %%
#tuning parameters
from sklearn.model_selection import GridSearchCV
n_estimators_range=[10,100,500,1000]
max_depth_range=[None,5,8,15,30]
min_samples_split_range=[2,5,10,50,100]
min_samples_leaf_range=[1,2,5,10]
param_grid = dict(n_estimators=n_estimators_range, max_depth=max_depth_range, min_samples_leaf=min_samples_leaf_range, min_samples_split=min_samples_split_range)
grid = GridSearchCV(estimator=classifier, param_grid=param_grid, n_jobs=-1,scoring='roc_auc')
grid_result = grid.fit(x_train2,y_train2)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
#for mean, stdev, param in zip(means, stds, params):
    #print("%f (%f) with: %r" % (mean, stdev, param))
#(Result is too long on github)
# Out:
# Best: 0.788384 using {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 1000}

# %%
rfc_model=grid.best_estimator_
rfc_model.fit(x_train2,y_train2)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred_rfc_2=rfc_model.predict_proba(x_test2)[:,1]
fpr_rfc, tpr_rfc, _ = roc_curve(y_test2, y_pred_rfc_2)
plt.plot(fpr_rfc, tpr_rfc, label='RFC')
plt.show()
metrics.auc(fpr_rfc, tpr_rfc)
# cm_rfc=confusion_matrix(y_test,y_pred_rfc)
# print(cm_rfc)
# Out:
# 0.79316160748186493

# %% [markdown]
# #### SVM

# %%
C = [0.05,0.1,0.5,1,1.5,2]
gamma = [0.005,0.01, 0.05, 0.1, 0.5]
svc_lin = svm.SVC(kernel="rbf", probability=True)
svc_rbf = svm.SVC(kernel="linear", probability=True)
svc_lin_cv = GridSearchCV(svc_lin, param_grid={"C":C},scoring='roc_auc')
svc_rbf_cv = GridSearchCV(svc_rbf, param_grid={"C":C, "gamma":gamma}, scoring='roc_auc')
svc_lin_cv.fit(x_train2, y_train2)
svc_rbf_cv.fit(x_train2, y_train2)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [0.05, 0.1, 0.5, 1, 1.5, 2], 'gamma': [0.005, 0.01, 0.05, 0.1, 0.5]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
svc_lin_model=svc_lin_cv.best_estimator_
svc_lin_model.fit(x_train2,y_train2)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred_svc_lin=svc_lin_model.predict_proba(x_test2)[:,1]
fpr_svc_lin, tpr_svc_lin, _ = roc_curve(y_test2, y_pred_svc_lin)
plt.plot(fpr_svc_lin, tpr_svc_lin, label='RFC')
plt.show()
metrics.auc(fpr_svc_lin, tpr_svc_lin)
# cm_svc_lin=confusion_matrix(y_test,y_pred)
# print(cm_svc_lin)
# Out:
# 0.76937711076916926

# %%
svc_rbf_model=svc_rbf_cv.best_estimator_
svc_rbf_model.fit(x_train2,y_train2)
# Out:
# SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.005, kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred_svc_rbf=svc_rbf_model.predict_proba(x_test2)[:,1]
fpr_svc_rbf, tpr_svc_rbf, _ = roc_curve(y_test2, y_pred_svc_rbf)
plt.plot(fpr_svc_rbf, tpr_svc_rbf, label='SVC-rbf')
plt.show()
metrics.auc(fpr_svc_rbf, tpr_svc_rbf)
# Out:
# 0.77457285026278444

# %%
plt.figure()
# plt.xlim(0, 0.2)
# plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr, tpr_lr, label='LR')
plt.plot(fpr_rfc, tpr_rfc, label='RF')
plt.plot(fpr_svc_lin, tpr_svc_lin, label='SVM-lin')
plt.plot(fpr_svc_rbf, tpr_svc_rbf, label='SVC-rbf')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (Label 2)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Label 1

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1=train_test_split(DF2,y1,test_size=0.2,random_state=42)

# %% [markdown]
# #### Logistic Regression

# %%
grid_lr.fit(x_train1, y_train1)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': array([ 1.]), 'penalty': ['l1', 'l2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
lr_1=grid_lr.best_estimator_
lr_1.fit(x_train1,y_train1)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred_lr_1_prob=lr_1.predict_proba(x_test1)[:, 1]
fpr_lr_1, tpr_lr_1, _ = roc_curve(y_test1, y_pred_lr_1_prob)
plt.plot(fpr_lr_1, tpr_lr_1, label='LR')
plt.show()
metrics.auc(fpr_lr_1, tpr_lr_1)
# Out:
# 0.691639072847682

# %% [markdown]
# #### Random forest

# %%
grid_result = grid.fit(x_train1,y_train1)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
# Out:
# Best: 0.698931 using {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 500}

# %%
rfc_model_1=grid.best_estimator_
rfc_model_1.fit(x_train1,y_train1)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=30, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred_rfc_1=rfc_model_1.predict_proba(x_test1)[:,1]
fpr_rfc_1, tpr_rfc_1, _ = roc_curve(y_test1, y_pred_rfc_1)
plt.plot(fpr_rfc_1, tpr_rfc_1, label='RFC-1')
plt.show()
metrics.auc(fpr_rfc_1, tpr_rfc_1)
# Out:
# 0.6992886926661761

# %%
plt.figure()
# plt.xlim(0, 0.2)
# plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr_1, tpr_lr_1, label='LR')
plt.plot(fpr_rfc_1, tpr_rfc_1, label='RF')
# plt.plot(fpr_svc_lin, tpr_svc_lin, label='SVM-lin')
# plt.plot(fpr_svc_rbf, tpr_svc_rbf, label='SVC-rbf')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (Label 1)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Lable 0

# %%
from sklearn.model_selection import train_test_split
x_train0,x_test0,y_train0,y_test0=train_test_split(DF2,y0,test_size=0.2,random_state=42)

# %%
grid_lr.fit(x_train0, y_train0)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': array([ 1.]), 'penalty': ['l1', 'l2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
lr_0=grid_lr.best_estimator_
lr_0.fit(x_train1,y_train1)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred_lr_0_prob=lr_0.predict_proba(x_test0)[:, 1]
fpr_lr_0, tpr_lr_0, _ = roc_curve(y_test0, y_pred_lr_0_prob)
plt.plot(fpr_lr_0, tpr_lr_0, label='LR')
plt.show()
metrics.auc(fpr_lr_0, tpr_lr_0)
# Out:
# 0.76962513722940507

# %% [markdown]
# #### Random Forest

# %%
grid_result = grid.fit(x_train0,y_train0)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
# Out:
# Best: 0.830570 using {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 500}

# %%
rfc_model_0=grid.best_estimator_
rfc_model_0.fit(x_train0,y_train0)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred_rfc_0=rfc_model_0.predict_proba(x_test0)[:,1]
fpr_rfc_0, tpr_rfc_0, _ = roc_curve(y_test0, y_pred_rfc_0)
plt.plot(fpr_rfc_0, tpr_rfc_0, label='RFC-0')
plt.show()
metrics.auc(fpr_rfc_0, tpr_rfc_0)
# Out:
# 0.86197120047750508

# %%
plt.figure()
# plt.xlim(0, 0.2)
# plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr_0, tpr_lr_0, label='LR')
plt.plot(fpr_rfc_0, tpr_rfc_0, label='RF')
# plt.plot(fpr_svc_lin, tpr_svc_lin, label='SVM-lin')
# plt.plot(fpr_svc_rbf, tpr_svc_rbf, label='SVC-rbf')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (Label 0)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### XGBoost

# %%
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
import xgboost as xgb
from skopt import BayesSearchCV
from sklearn.model_selection import StratifiedKFold

# SETTINGS - CHANGE THESE TO GET SOMETHING MEANINGFUL
ITERATIONS = 10 # 1000
TRAINING_SIZE = 100000 # 20000000
TEST_SIZE = 25000

# %%
x_train2['Review_times']=pd.to_numeric(x_train2['Review_times'])
x_test2['Review_times']=pd.to_numeric(x_test2['Review_times'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
bayes_cv_tuner = BayesSearchCV(
    estimator = xgb.XGBClassifier(
        n_jobs = 1,
        objective = 'binary:logistic',
        silent=1,
        tree_method='approx'
    ),
    search_spaces = {
        'learning_rate': (0.01, 1.0, 'log-uniform'),
        'min_child_weight': (0, 10),
        'max_depth': (0, 50),
        'max_delta_step': (0, 20),
        'subsample': (0.01, 1.0, 'uniform'),
        'colsample_bytree': (0.01, 1.0, 'uniform'),
        'colsample_bylevel': (0.01, 1.0, 'uniform'),
        'reg_lambda': (1e-9, 1000, 'log-uniform'),
        'reg_alpha': (1e-9, 1.0, 'log-uniform'),
        'gamma': (1e-9, 0.5, 'log-uniform'),
        'min_child_weight': (0, 5),
        'n_estimators': (50, 100),
        'scale_pos_weight': (1e-6, 500, 'log-uniform')
    },  
    scoring='roc_auc',
    cv = StratifiedKFold(
        n_splits=5,
        shuffle=True,
        random_state=42
    ),
    n_jobs = 3,
    n_iter = ITERATIONS,   
    verbose = 0,
    refit = True,
    random_state = 42
)

def status_print(optim_result):
    """Status callback durring bayesian hyperparameter search"""
    
    # Get all the models tested so far in DataFrame format
    all_models = pd.DataFrame(bayes_cv_tuner.cv_results_)    
    
    # Get current parameters and the best parameters    
    best_params = pd.Series(bayes_cv_tuner.best_params_)
    print('Model #{}\nBest ROC-AUC: {}\nBest params: {}\n'.format(
        len(all_models),
        np.round(bayes_cv_tuner.best_score_, 4),
        bayes_cv_tuner.best_params_
    ))
    
    # Save all model results
    clf_name = bayes_cv_tuner.estimator.__class__.__name__
    all_models.to_csv(clf_name+"_cv_results.csv")

# %%
result = bayes_cv_tuner.fit(x_train2.values, y_train2, callback=status_print)
# Out:
# Model #1
# Best ROC-AUC: 0.7284
# Best params: {'colsample_bylevel': 0.41600291926478072, 'colsample_bytree': 0.73044848574555188, 'gamma': 0.13031389926541354, 'learning_rate': 0.042815319280763466, 'max_delta_step': 13, 'max_depth': 21, 'min_child_weight': 2, 'n_estimators': 87, 'reg_alpha': 5.4975577392897861e-07, 'reg_lambda': 0.059360706359120489, 'scale_pos_weight': 0.060830282487222144, 'subsample': 0.13556548021189216}
#
# Model #2
# Best ROC-AUC: 0.7632
# Best params: {'colsample_bylevel': 0.83901447199775159, 'colsample_bytree': 0.88448212460705367, 'gamma': 4.3586846084807948e-07, 'learning_rate': 0.79881794627812419, 'max_delta_step': 17, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 68, 'reg_alpha': 0.00052669830037015467, 'reg_lambda': 276.54244755742252, 'scale_pos_weight': 0.30164107718431421, 'subsample': 0.99237105986371343}
#
# Model #3
# Best ROC-AUC: 0.7645
# ...

# %%
xgboost=bayes_cv_tuner.best_estimator_
xgboost.fit(x_train2,y_train2)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree',
#        colsample_bylevel=0.95592320644682904,
#        colsample_bytree=0.70361523017515237, gamma=0.038236134438795949,
#        learning_rate=0.067864425217791471, max_delta_step=8, max_depth=11,
#        min_child_weight=0, missing=None, n_estimators=69, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0.00022356829889037284, reg_lambda=1.2908532337409298e-07,
#        scale_pos_weight=4.7358848611911704, seed=None, silent=1,
#        subsample=0.44995780155093512, tree_method='approx')

# %%
y_pred_Xgb_2=xgboost.predict_proba(x_test2)[:,1]
fpr_xgb_2, tpr_rfc_2, _ = roc_curve(y_test2, y_pred_Xgb_2)
plt.plot(fpr_xgb_2, tpr_rfc_2)
plt.show()
metrics.auc(fpr_xgb_2, tpr_rfc_2)
# Out:
# 0.76325013488939075

# %%
result_1 = bayes_cv_tuner.fit(x_train1.values, y_train1, callback=status_print)
# Out:
# Model #1
# Best ROC-AUC: 0.634
# Best params: {'colsample_bylevel': 0.41600291926478072, 'colsample_bytree': 0.73044848574555188, 'gamma': 0.13031389926541354, 'learning_rate': 0.042815319280763466, 'max_delta_step': 13, 'max_depth': 21, 'min_child_weight': 2, 'n_estimators': 87, 'reg_alpha': 5.4975577392897861e-07, 'reg_lambda': 0.059360706359120489, 'scale_pos_weight': 0.060830282487222144, 'subsample': 0.13556548021189216}
#
# Model #2
# Best ROC-AUC: 0.6804
# Best params: {'colsample_bylevel': 0.83901447199775159, 'colsample_bytree': 0.88448212460705367, 'gamma': 4.3586846084807948e-07, 'learning_rate': 0.79881794627812419, 'max_delta_step': 17, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 68, 'reg_alpha': 0.00052669830037015467, 'reg_lambda': 276.54244755742252, 'scale_pos_weight': 0.30164107718431421, 'subsample': 0.99237105986371343}
#
# Model #3
# Best ROC-AUC: 0.6804
# ...

# %%
xgboost_1=result_1.best_estimator_
xgboost_1.fit(x_train1.values,y_train1)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree',
#        colsample_bylevel=0.83901447199775159,
#        colsample_bytree=0.88448212460705367, gamma=4.3586846084807948e-07,
#        learning_rate=0.79881794627812419, max_delta_step=17, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=68, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0.00052669830037015467, reg_lambda=276.54244755742252,
#        scale_pos_weight=0.30164107718431421, seed=None, silent=1,
#        subsample=0.99237105986371343, tree_method='approx')

# %%
y_pred_Xgb_1=xgboost_1.predict_proba(x_test1.values)[:,1]
fpr_xgb_1, tpr_xgb_1, _ = roc_curve(y_test1, y_pred_Xgb_1)
plt.plot(fpr_xgb_1, tpr_xgb_1)
plt.show()
metrics.auc(fpr_xgb_1, tpr_xgb_1)
# Out:
# 0.68409931730847839

# %%
result_0 = bayes_cv_tuner.fit(x_train0.values, y_train0, callback=status_print)
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x10a211898>>
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/xgboost/core.py", line 366, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# Model #1
# Best ROC-AUC: 0.7751
# Best params: {'colsample_bylevel': 0.41600291926478072, 'colsample_bytree': 0.73044848574555188, 'gamma': 0.13031389926541354, 'learning_rate': 0.042815319280763466, 'max_delta_step': 13, 'max_depth': 21, 'min_child_weight': 2, 'n_estimators': 87, 'reg_alpha': 5.4975577392897861e-07, 'reg_lambda': 0.059360706359120489, 'scale_pos_weight': 0.060830282487222144, 'subsample': 0.13556548021189216}
#
# Model #2
# Best ROC-AUC: 0.806
# ...

# %%
xgboost_0=result_0.best_estimator_
xgboost_0.fit(x_train0.values,y_train0)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree',
#        colsample_bylevel=0.95592320644682904,
#        colsample_bytree=0.70361523017515237, gamma=0.038236134438795949,
#        learning_rate=0.067864425217791471, max_delta_step=8, max_depth=11,
#        min_child_weight=0, missing=None, n_estimators=69, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0.00022356829889037284, reg_lambda=1.2908532337409298e-07,
#        scale_pos_weight=4.7358848611911704, seed=None, silent=1,
#        subsample=0.44995780155093512, tree_method='approx')

# %%
y_pred_Xgb_0=xgboost_0.predict_proba(x_test0.values)[:,1]
fpr_xgb_0, tpr_xgb_0, _ = roc_curve(y_test0, y_pred_Xgb_0)
plt.plot(fpr_xgb_0, tpr_xgb_0)
plt.show()
metrics.auc(fpr_xgb_0, tpr_xgb_0)
# Out:
# 0.84943669327762439

# %%
importance_dict = {}
for import_type in ['weight', 'gain', 'cover']:
    importance_dict['xgBoost-'+import_type] = xgboost.get_booster().get_score(importance_type=import_type)

# %%
ft=pd.DataFrame(importance_dict)
ft.sort_values(by=['xgBoost-gain'],inplace=True)

# %%
ft.to_csv('/Users/richard/Desktop/ft.csv')

# %%
plt.figure()
# plt.xlim(0, 0.2)
# plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr, tpr_lr, label='LR')
plt.plot(fpr_rfc, tpr_rfc, label='RF')
plt.plot(fpr_svc_lin, tpr_svc_lin, label='SVM-lin')
plt.plot(fpr_svc_rbf, tpr_svc_rbf, label='SVC-rbf')
plt.plot(fpr_xgb_2, tpr_rfc_2, label='XGboost')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (Label 2)')
plt.legend(loc='best')
plt.show()

# %%
plt.figure()
# plt.xlim(0, 0.2)
# plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr_1, tpr_lr_1, label='LR')
plt.plot(fpr_rfc_1, tpr_rfc_1, label='RF')
plt.plot(fpr_xgb_1, tpr_xgb_1, label='XGboost')
# plt.plot(fpr_svc_lin, tpr_svc_lin, label='SVM-lin')
# plt.plot(fpr_svc_rbf, tpr_svc_rbf, label='SVC-rbf')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (Label 1)')
plt.legend(loc='best')
plt.show()

# %%
plt.figure()
# plt.xlim(0, 0.2)
# plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr_0, tpr_lr_0, label='LR')
plt.plot(fpr_rfc_0, tpr_rfc_0, label='RF')
plt.plot(fpr_xgb_0, tpr_xgb_0, label='XGboost')
# plt.plot(fpr_svc_lin, tpr_svc_lin, label='SVM-lin')
# plt.plot(fpr_svc_rbf, tpr_svc_rbf, label='SVC-rbf')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (Label 0)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Reivision System

# %%
score_pred=rfc_model.predict(DF2)

# %%
inauc=[]
for i in range(len(y_new)):
    if y_new[i]!=score_pred[i]:
        inauc.append(i)

# %%
inauc_score=[df_new['Score'][i] for i in inauc]
inauc_topic=[df_new['Topic'][i] for i in inauc]

# %%
pd.DataFrame(inauc_score,inauc_topic)
# Out:
#                                                        0
# Overpriced.                                          8.8
# Bed GREAT! Spa GREAT! Air Freshener everywhere ...   7.5
# Not coming back                                      5.0
# Average hotel nothing outstanding                    7.5
# We love Vegas and can't wait to be back!             6.7
# Book the hotel after watching ''Hangover''...        7.1
# Enjoyable comfortable 5 night stay.                  6.7
# Proximity to everything.                             7.5
# Very comfortable bed and clean bathroom.             7.9
# Caesar Experience                                    7.1
# Disappointed with my stay. This is a long time ...   4.6
# Don't stay here. Just don't.                         6.3
# See above                                            7.5
# ON ARRIVAL THEY SAID THAT THE ROOM THAT WE HAD ...   7.1
# Overall a very enjoyable stay. Well located, st...   7.9
# ...
